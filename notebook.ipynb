# %% [markdown]
# <center><img src="redpopcorn.jpg"></center>

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry.
#
# You work for a production company that specializes in nostalgic styles. You want to do some research on movies released in the 1990's. You'll delve into Netflix data and perform exploratory data analysis to better understand this awesome movie decade!
#
# You have been supplied with the dataset `netflix_data.csv`, along with the following table detailing the column names and descriptions. Feel free to experiment further after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# %%
# Filtrar Apenas Filmes de 1990
netflix_df_90s = netflix_df[(netflix_df['release_year'] >= 1990) & (netflix_df['release_year'] < 2000)]

# Conta quantos filmes foram lançados por ano
filmes_por_ano = netflix_df_90s['release_year'].value_counts().sort_index()



# Encontrar a duração mais frequente entre os filmes dos anos 90
duration = int(df_90s['duration'].mode()[0])

# Criar um histograma da duração dos filmes dos anos 90
plt.hist(df_90s['duration'], bins=20, edgecolor='black')
plt.title('Distribuição de Duração dos Filmes da Netflix (Anos 90)')
plt.xlabel('Duração (minutos)')
plt.ylabel('Número de Filmes')
plt.show()

# Cria o gráfico de linha
plt.figure(figsize=(10, 6))
plt.plot(filmes_por_ano.index, filmes_por_ano.values, marker='o')
plt.title("Número de Filmes Lançados por Ano na Netflix (Década de 1990)")
plt.xlabel("Ano de Lançamento")
plt.ylabel("Número de Filmes")
plt.grid(True)
plt.tight_layout()
plt.show()



# Filtrar apenas os filmes de gênero "Action"
netflix_df_90s_action = netflix_df_90s[netflix_df_90s['genre'] == 'Action']

short_movie_count = 0


for index, row in netflix_df_90s_action.iterrows():
    if row['duration'] < 90:
        short_movie_count += 1

print("Número de filmes de ação curtos dos anos 90 na Netflix:", short_movie_count)
# Out:
# Número de filmes de ação curtos dos anos 90 na Netflix: 7
